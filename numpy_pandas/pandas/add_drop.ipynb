# %%
import pandas as pd
import numpy as np
df_book = pd.read_excel('./Excel_data/students.xlsx')

# %%
df_book.head(2)
# Out:
#    id estudiante fecha_inicio  edad  carrera_id
# 0   1    Riannon   2020-03-07    23         3.0
# 1   2    Enrique   2020-08-28    23         2.0

# %%
df_book.drop('edad',axis=1).head(2)
# si quieres un borrado permanente se usara ,inplace=True o df_book =
# Out:
#    id estudiante fecha_inicio  carrera_id
# 0   1    Riannon   2020-03-07         3.0
# 1   2    Enrique   2020-08-28         2.0

# %%
df_book.head(2)
# Out:
#    id estudiante fecha_inicio  edad  carrera_id
# 0   1    Riannon   2020-03-07    23         3.0
# 1   2    Enrique   2020-08-28    23         2.0

# %%
df_book.drop(0,axis=0).head(2)
# borrar filas
# Out:
#    id estudiante fecha_inicio  edad  carrera_id
# 1   2    Enrique   2020-08-28    23         2.0
# 2   3    Jeremie   2020-02-27    24         5.0

# %%
df_book['columna']=df_book['edad']-df_book['carrera_id'] #crear una columna en python 
df_book['columna2']=np.nan
df_book.head(2)
# Out:
#    id estudiante fecha_inicio  edad  carrera_id  columna  columna2
# 0   1    Riannon   2020-03-07    23         3.0     20.0       NaN
# 1   2    Enrique   2020-08-28    23         2.0     21.0       NaN

# %%
data = np.arange(0,df_book.shape[0])
df_book['rango'] = data
df_book.head(2)
# Out:
#    id estudiante fecha_inicio  edad  carrera_id  columna  columna2  rango
# 0   1    Riannon   2020-03-07    23         3.0     20.0       NaN      0
# 1   2    Enrique   2020-08-28    23         2.0     21.0       NaN      1

# %%
df_book.append(df_book)
# Out:
# C:\Users\LeoAl\AppData\Local\Temp\ipykernel_12292\1185068273.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_book.append(df_book)
#     id  estudiante fecha_inicio  edad  carrera_id  columna  columna2  rango
# 0    1     Riannon   2020-03-07    23         3.0     20.0       NaN      0
# 1    2     Enrique   2020-08-28    23         2.0     21.0       NaN      1
# 2    3     Jeremie   2020-02-27    24         5.0     19.0       NaN      2
# 3    4       Terza   2021-01-26    28         3.0     25.0       NaN      3
# 4    5        Luce   2020-10-07    28         2.0     26.0       NaN      4
# 5    6   Shandeigh   2022-07-07    18         1.0     17.0       NaN      5
# 6    7      Cornie   2021-10-14    23         3.0     20.0       NaN      6
# 7    8    Barbabra   2022-02-19    19         1.0     18.0       NaN      7
# ...
